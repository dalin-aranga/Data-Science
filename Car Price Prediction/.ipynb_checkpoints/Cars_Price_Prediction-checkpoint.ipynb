# %%
# import libry
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data set
cars = pd.read_csv('CarPrice_Assignment.csv')

# %%
# show first 5 rows
cars.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
# checking shape
cars.shape
# Out:
# (205, 26)

# %%
# check it has null values
cars.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
# Check data Types ech columns
cars.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
# check It has duplicate value
cars[cars.duplicated()]
# Out:
# Empty DataFrame
# Columns: [car_ID, symboling, CarName, fueltype, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
# replace car name to Company NAme and Add Column Company name
CompanyName = cars['CarName'].apply(lambda x : x.split(' ')[0])
cars.insert(1,'CompanyName',CompanyName)

# %%
# Drop CarName Column
cars.drop(columns=['CarName'],axis=1,inplace = True)

# %%
cars
# Out:
#      car_ID  CompanyName  symboling fueltype aspiration doornumber  \
# 0         1  alfa-romero          3      gas        std        two
# 1         2  alfa-romero          3      gas        std        two
# 2         3  alfa-romero          1      gas        std        two
# 3         4         audi          2      gas        std       four
# 4         5         audi          2      gas        std       four
# ..      ...          ...        ...      ...        ...        ...
# 200     201        volvo         -1      gas        std       four
# 201     202        volvo         -1      gas      turbo       four
# 202     203        volvo         -1      gas        std       four
# 203     204        volvo         -1   diesel      turbo       four
# 204     205        volvo         -1      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0    convertible        rwd          front       88.6  ...         130
# ...

# %%
# Checking company Names
cars['CompanyName'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %%
# replace compny name real Name
def replaceName(oldName,NewName):
    cars['CompanyName'].replace(oldName,NewName,inplace=True)
    
replaceName('maxda','mazda')
replaceName('porcshce','porsche')
replaceName('toyouta','toyota')
replaceName('vokswagen','volkswagen')
replaceName('vw','volkswagen')

# %%
# Check again Name is correct
cars['CompanyName'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
cars.head()
# Out:
#    car_ID  CompanyName  symboling fueltype aspiration doornumber      carbody  \
# 0       1  alfa-romero          3      gas        std        two  convertible
# 1       2  alfa-romero          3      gas        std        two  convertible
# 2       3  alfa-romero          1      gas        std        two    hatchback
# 3       4         audi          2      gas        std       four        sedan
# 4       5         audi          2      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0        rwd          front       88.6  ...         130        mpfi
# 1        rwd          front       88.6  ...         130        mpfi
# 2        rwd          front       94.5  ...         152        mpfi
# 3        fwd          front       99.8  ...         109        mpfi
# 4        4wd          front       99.4  ...         136        mpfi
#
#    boreratio  stroke compressionratio horsepower  peakrpm citympg  highwaympg  \
# ...

# %%
plt.figure(figsize=(20,10))

plt.subplot(1,2,1)
sns.boxplot(y=cars['price'])
plt.title('Box plot in price')

plt.subplot(1,2,2)
sns.distplot(cars['price'])
plt.title('Box Distribution in price')

plt.show()

# %%
cars.price.describe(percentiles=[0.25,0.5,0.75,0.8,0.9,1])
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# 80%      17493.800000
# 90%      22563.000000
# 100%     45400.000000
# max      45400.000000
# Name: price, dtype: float64

# %% [markdown]
# 1. According to graph and describe fuction we can get most cars price between 12500 adn 17500

# %%
plt.figure(figsize=(25,7))

plt.subplot(1,3,1)
ax = sns.countplot(x='CompanyName',data=cars)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90,fontdict={'fontsize':14})
plt.title('Company Count Plot Graph 01',color='g',fontdict={'fontsize':18,'fontweight':'bold'})
plt.xlabel('Company Names',fontdict={'fontsize':16,'fontweight':'bold'})

plt.subplot(1,3,2)
ax = sns.countplot(x='fueltype',data=cars)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90,fontdict={'fontsize':14})
plt.title('Fuel Count Plot Graph 02',color='r',fontdict={'fontsize':18,'fontweight':'bold'})
plt.xlabel('Fuel Types',fontdict={'fontsize':16,'fontweight':'bold'})

plt.subplot(1,3,3)
ax = sns.countplot(x='carbody',data=cars)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90,fontdict={'fontsize':16})
plt.title('Carbody Count Plot Graph 03',color='g',fontdict={'fontsize':18,'fontweight':'bold'})
plt.xlabel('Carbidy Types',fontdict={'fontsize':16,'fontweight':'bold'})
plt.show()

# %% [markdown]
# 1. According to graph 01 toyota cars is high demand
# 2. According to graph 02 gas cars is high demand
# 5. According to graph 05 hactchback carbidy types cars is high demand

# %%
plt.figure(figsize=(25,7))

plt.subplot(1,2,1)
sns.countplot(x='symboling', data=cars)
plt.title('Symboling Count Plot',color='y',fontdict={'fontsize':18,'fontweight':'bold'})

plt.subplot(1,2,2)
sns.boxplot(x=cars['symboling'],y=cars['price'])
plt.title('Symboling v price',color='g',fontdict={'fontsize':18,'fontweight':'bold'})
plt.show()

# %% [markdown]
# 1. According to first graph symboling  between 0 to 1 range cars most sold.
# 2. The cars with -1 symboling seems to be high priced (as it makes sense too, insurance risk rating -1 is quite good). But it seems that symboling with 3 value has the price range similar to -2 value. There is a dip in price at symboling 1.

# %%
plt.figure(figsize=(25,7))

plt.subplot(1,2,1)
sns.countplot(x='enginetype', data=cars)
plt.title('Engine Type Count Plot',color='y',fontdict={'fontsize':18,'fontweight':'bold'})

plt.subplot(1,2,2)
sns.boxplot(x=cars['enginetype'],y=cars['price'])
plt.title('Engine Type v price',color='g',fontdict={'fontsize':18,'fontweight':'bold'})
plt.show()

# %%
df = cars.groupby(['enginetype'])['price'].mean().sort_values(ascending = False)
df.plot.bar()
plt.title('Engine Type v price',color='g',fontdict={'fontsize':18,'fontweight':'bold'})
plt.show()

# %% [markdown]
# 1. ohcv has the highest price range (While dohcv has only one row), ohc and ohcf have the low price range.

# %%
plt.figure(figsize=(25,6))

df = cars.groupby(['CompanyName'])['price'].mean().sort_values(ascending = False)
df.plot.bar()
plt.title('Company Name v price',color='g',fontdict={'fontsize':18,'fontweight':'bold'})
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
df = cars.groupby(['carbody'])['price'].mean().sort_values(ascending = False)
df.plot.bar()
plt.title('Car Body v price',color='g',fontdict={'fontsize':18,'fontweight':'bold'})
plt.legend()
plt.show()

plt.figure(figsize=(6,6))
df = cars.groupby(['fueltype'])['price'].mean().sort_values(ascending = False)
df.plot.bar()
plt.title('Fuel Type v price',color='g',fontdict={'fontsize':18,'fontweight':'bold'})
plt.legend()
plt.show()

# %% [markdown]
# 1. Jaguar and Buick seem to have highest average price.
# 2. diesel has higher average price than gas.
# 3. hardtop and convertible have higher average price.

# %%
plt.figure(figsize=(15,6))

plt.subplot(1,2,1)
sns.countplot(x='doornumber',data = cars)
plt.title('Door Number Count Plot',color='black',fontdict={'fontsize':18,'fontweight':'bold'})

plt.subplot(1,2,2)
sns.boxplot(x=cars['doornumber'],y=cars.price)
plt.title('Door Number vs Price Box Plot',color='black',fontdict={'fontsize':18,'fontweight':'bold'})

plt.show()


plt.figure(figsize=(15,6))

plt.subplot(1,2,1)
sns.countplot(x='aspiration',data = cars)
plt.title('aspiration Count Plot',color='black',fontdict={'fontsize':18,'fontweight':'bold'})

plt.subplot(1,2,2)
sns.boxplot(x=cars['aspiration'],y=cars.price)
plt.title('aspiration vs Price Box Plot',color='black',fontdict={'fontsize':18,'fontweight':'bold'})

plt.show()

# %% [markdown]
# 1. doornumber variable is not affacting the price much. There is no sugnificant difference between the categories in it.
# 2. It seems aspiration with turbo have higher price range than the std(though it has some high values outside the whiskers.)

# %%
def count_plot(colums, fig):
    plt.figure(figsize=(15,20))
    plt.subplot(4,2,fig)
    sns.countplot(x=colums,data = cars)
    plt.title(f'{colums} Count Plot',color='black',fontdict={'fontsize':18,'fontweight':'bold'})

    plt.subplot(4,2,fig+1)
    sns.boxplot(x=cars[colums],y=cars.price)
    plt.title(f'{colums} vs Price Box Plot',color='black',fontdict={'fontsize':18,'fontweight':'bold'})
    plt.show()

# %%
count_plot('enginelocation',1)
count_plot('cylindernumber',3)
count_plot('fuelsystem',5)
count_plot('drivewheel',7)

# %% [markdown]
# 1. Very few datapoints for enginelocation categories to make an inference.
# 2. Most common number of cylinders are four, six and five. Though eight cylinders have the highest price range.
# 3. mpfi and 2bbl are most common type of fuel systems. mpfi and idi having the highest price range. But there are few data for other categories to derive any meaningful inference
# 4. A very significant difference in drivewheel category. Most high ranged cars seeme to prefer rwd drivewheel.

# %%
def numerical_data(columns,y):
    plt.figure(figsize=(15,15))
    plt.subplot(2,2,y)
    sns.scatterplot(x=cars[columns], y=cars.price)
    plt.title(f'{columns} vs price  Scatter Plot')

# %%
numerical_data('carlength',1)
numerical_data('carwidth',2)
numerical_data('carheight',3)
numerical_data('curbweight',4)

# %% [markdown]
# 1. carwidth, carlength and curbweight seems to have a poitive correlation with price.
# 2. carheight doesn't show any significant trend with price.
